# %%
import matplotlib.pyplot as plt

def plot_concentration_curve(df, title="Airport Noise Concentration Curve"):
    # 1. 准备数据（确保已按 GDP 排序）
    df = df.sort_values('per_capita_gdp')
    pop_w = df['pop_exposed'] / df['pop_exposed'].sum()
    noise_h = (df['pop_exposed'] * df['y_mid']) / (df['pop_exposed'] * df['y_mid']).sum()
    
    # 2. 计算累计占比
    cum_pop = np.concatenate([[0], np.cumsum(pop_w)])
    cum_noise = np.concatenate([[0], np.cumsum(noise_h)])
    
    # 3. 绘图
    plt.figure(figsize=(6, 6))
    plt.plot([0, 1], [0, 1], color='grey', linestyle='--', label='Line of Equality') # 对角线
    plt.plot(cum_pop, cum_noise, color='#2c7bb6', linewidth=2, label='Concentration Curve') # 集中曲线
    
    # 填充面积（视觉化 CI）
    plt.fill_between(cum_pop, cum_pop, cum_noise, color='#2c7bb6', alpha=0.2)
    
    plt.xlabel('Cumulative share of population (ranked by GDP per capita)')
    plt.ylabel('Cumulative share of noise exposure burden')
    plt.title(title)
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()
# Out:
# Duplicate key in file WindowsPath('d:/Software/anaconda3/envs/gis/lib/site-packages/matplotlib/mpl-data/matplotlibrc'), line 272 ('font.sans-serif: DejaVu Sans, Bitstream Vera Sans, Computer Modern Sans Serif, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif')
# Duplicate key in file WindowsPath('d:/Software/anaconda3/envs/gis/lib/site-packages/matplotlib/mpl-data/matplotlibrc'), line 414 ('axes.unicode_minus: True  # use Unicode for the minus symbol rather than hyphen.  See')
