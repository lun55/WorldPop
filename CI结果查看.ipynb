# %%
import pandas as pd

# %%
df = pd.read_csv("F:\机场噪音\CI_Trend_Summary\Trend_Detail_L2_oneday.csv")

# %%
df
# Out:
#           gaul0_name                         gaul1_name  \
# 0        Afghanistan                              Kabul
# 1        Afghanistan                              Kabul
# 2           Akrotiri  Administrative Unit Not Available
# 3            Albania                              Berat
# 4            Albania                              Berat
# ...              ...                                ...
# 20565       Zimbabwe                   Mashonaland East
# 20566       Zimbabwe                   Mashonaland West
# 20567       Zimbabwe                   Mashonaland West
# 20568       Zimbabwe                 Matebeleland North
# 20569  Åland Islands  Administrative Unit Not Available
#
#                               gaul2_name  gaul1_code  gaul2_code    202110  \
# 0                               Deh Sabz      2411.0    123871.0       NaN
# 1                                  Kabul      2411.0    123875.0       NaN
# ...

# %%
df[(df['202110']>0)&(df['gaul0_name']=='China')]
# Out:
#      gaul0_name         gaul1_name                         gaul2_name  \
# 4795      China     Anhui Province                             Anqing
# 4797      China     Anhui Province                             Bozhou
# 4798      China     Anhui Province                            Chizhou
# 4800      China     Anhui Province                             Fuyang
# 4801      China     Anhui Province                              Hefei
# ...         ...                ...                                ...
# 5046      China    Yunnan Province  Chuxiong Yi Autonomous Prefecture
# 5053      China    Yunnan Province                               Yuxi
# 5057      China  Zhejiang Province                            Jiaxing
# 5064      China  Zhejiang Province                            Wenzhou
# 5065      China  Zhejiang Province                           Zhoushan
#
#       gaul1_code  gaul2_code    202110    202210    202310  \
# 4795      2531.0    124748.0  0.052455  0.015961 -0.121490
# ...

# %%
df[~df['202110'].isna()]
# Out:
#           gaul0_name                         gaul1_name  \
# 2           Akrotiri  Administrative Unit Not Available
# 5            Albania                              Diber
# 7            Albania                              Diber
# 8            Albania                              Diber
# 9            Albania                             Durres
# ...              ...                                ...
# 20565       Zimbabwe                   Mashonaland East
# 20566       Zimbabwe                   Mashonaland West
# 20567       Zimbabwe                   Mashonaland West
# 20568       Zimbabwe                 Matebeleland North
# 20569  Åland Islands  Administrative Unit Not Available
#
#                               gaul2_name  gaul1_code  gaul2_code    202110  \
# 2      Administrative Unit Not Available      3290.0    133967.0  0.040061
# 5                        Bashkia Bulqize      3292.0    133973.0 -0.000180
# ...

# %%
df['gaul1_code'] = df['gaul1_code'].astype(int)

# %%
df.to_csv("test.csv", index=False)
