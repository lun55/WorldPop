# %%
import geopandas as gpd
import pandas as pd

# %%
gdp = pd.read_csv("F:\机场噪音\GDP\L0_GDP_2015.csv")

# %%
gdp.sort_values(by='total_gdp', ascending=False).head(30)
# Out:
#                                             gaul0_name     total_gdp
# 52                                               China  1.992986e+13
# 251                           United States of America  1.669692e+13
# 117                                              India  7.293526e+12
# 127                                              Japan  4.435817e+12
# 199                                 Russian Federation  3.628944e+12
# 95                                             Germany  3.557659e+12
# 37                                              Brazil  2.989062e+12
# 118                                          Indonesia  2.537275e+12
# 248  United Kingdom of Great Britain and Northern I...  2.462755e+12
# 88                                              France  2.405818e+12
# 157                                             Mexico  2.092603e+12
# 124                                              Italy  1.989305e+12
# 195                                  Republic Of Korea  1.651514e+12
# ...

# %%
df = gpd.read_file("F:/机场噪音/GAUL_2024_调整\rGAUL_2024_L2\GAUL_2024_L2.shp")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = gpd.read_file("F:\机场噪音\GDP\L0_GDP_2015.csv")
#
# NameError: name 'gpd' is not defined

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 45508 entries, 0 to 45507
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   iso3_code   45508 non-null  object
#  1   map_code    45508 non-null  object
#  2   gaul0_code  45508 non-null  int64
#  3   gaul0_name  45508 non-null  object
#  4   gaul1_code  45508 non-null  int64
#  5   gaul1_name  45508 non-null  object
#  6   gaul2_code  45508 non-null  int64
#  7   gaul2_name  45508 non-null  object
#  8   continent   45508 non-null  object
#  9   disp_en     45508 non-null  object
#  10  Shape_Leng  45508 non-null  float64
#  11  Shape_Area  45508 non-null  float64
#  12  geometry    45508 non-null  geometry
# dtypes: float64(2), geometry(1), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
df['']
